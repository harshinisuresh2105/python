# %%
#Exception handling using try-except

10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-1830975966.py in <cell line: 0>()
#       1 #Exception handling using try-except
#       2
# ----> 3 10/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# To clear the zero division error we use try method exception handling

# %%
try:
   a=10/2
   print(a)
except ZeroDivisionError:
   print("error:Division by zero is not allowed")
finally:
   print("Thank you")

# %%
try:
  num=int(input("Enter a number :  "))
  print(10/num)
except ZeroDivisionError:
  print("error:Division by zero is not allowed")
except ValueError:
  print("Invalid input : please enter the valid intput")
# Out:
# Enter a number :  k
# Invalid input : please enter the valid intput

# %%
try:
    age = int(input("Enter your age: "))
    print("You are", age, "years old.")
except:
    print("Please enter a valid age!")
# Out:
# Enter your age: 21
# You are 21 years old.

# %%
try:
  num1=int(input("Enter a number 1 : "))
  num2=int(input("Enter a number 2 : "))
  answer=(num1/num2)
  print(answer)
except (ZeroDivisionError,ValueError):
  print("Invalid input:Enter valid input")
# Out:
# Enter a number 1 : 20
# Enter a number 2 : 5
# 4.0
